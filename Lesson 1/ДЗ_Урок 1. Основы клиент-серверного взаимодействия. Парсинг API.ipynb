# %% [markdown]
# ### 1. Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
import requests
import json
from pprint import pprint

# %%
main_link = 'https://api.github.com'
user_name = 'Vitaas'
req = requests.get(f'{main_link}/users/{user_name}/repos')

# %%
pprint(req.json())
# Out:
# [{'archive_url': 'https://api.github.com/repos/Vitaas/-JS/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/Vitaas/-JS/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/Vitaas/-JS/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/Vitaas/-JS/branches{/branch}',
#   'clone_url': 'https://github.com/Vitaas/-JS.git',
#   'collaborators_url': 'https://api.github.com/repos/Vitaas/-JS/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/Vitaas/-JS/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/Vitaas/-JS/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/Vitaas/-JS/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/Vitaas/-JS/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/Vitaas/-JS/contributors',
#   'created_at': '2020-03-25T16:45:33Z',
#   'default_branch': 'master',
# ...

# %%
for i in req.json():
    print(i["name"])
# Out:
# -JS
# bjs-diplom
# bjs-homeworks
# Diploma-HTML-2
# GeekBrains--Python-Data-Science
# GeekBrains_Python
# git-homeworks-neuro
# GIT_-3
# neuro-startup
# NeuroStartUp
# Python_lesson-1

# %%
with open('repo.json','w') as f:
    json.dump(req.json(), f)

# %% [markdown]
# ### 2. Изучить список открытых API (https://www.programmableweb.com/category/all/apis). Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.

# %%
link = 'https://api.vk.com/method/users.get?user_id=4275042&v=5.52'
access_token = '1c6b3d421339b3c420182e5f38c1cc8f6eb2cd8364a7eba96270985e69a0b1e528fda090066264b130e92'

# %%
headers = {
    'Content-Type': 'application/json', \
    'Authorization': access_token
}

# %%
request = requests.get(f'{link}', headers = headers)

# %%
request.json()
# Out:
# {'error': {'error_code': 5,
#   'error_msg': 'User authorization failed: no access_token passed.',
#   'request_params': [{'key': 'user_id', 'value': '4275042'},
#    {'key': 'v', 'value': '5.52'},
#    {'key': 'method', 'value': 'users.get'},
#    {'key': 'oauth', 'value': '1'}]}}
